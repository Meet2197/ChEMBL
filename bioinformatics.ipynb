# %% [markdown]
# <a href="https://colab.research.google.com/github/Meet2197/ChEMBL/blob/main/bioinformatics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bioinformatics Project - Computational Drug Discovery
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 1, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
#
# Redundant code cells were deleted.
# Code cells for saving files to Google Drive has been deleted.
# ChEMBL Database
# The ChEMBL Database is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications. [Data as of March 25, 2020; ChEMBL version 26].
#
# Installing libraries
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
pip install chembl-webresource-client

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
target = new_client.target
target_query = target.search('human immunodeficiency viruses')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2    [{'xref_id': 'P15822', 'xref_name': None, 'xre...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 179  [{'xref_id': 'P35329', 'xref_name': None, 'xre...
# 180                                                 []
# 181                                                 []
# 182                                                 []
# 183                                                 []
#
#                            organism  \
# 0                      Homo sapiens
# 1      Human immunodeficiency virus
# 2                      Homo sapiens
# 3    Human immunodeficiency virus 1
# 4    Human immunodeficiency virus 2
# ..                              ...
# 179                    Mus musculus
# 180                    Homo sapiens
# 181                    Homo sapiens
# 182                    Homo sapiens
# 183                    Homo sapiens
#
#                                              pref_name  score  \
# 0                          Transcription factor HIVEP2   26.0
# 1                         Human immunodeficiency virus   21.0
# 2    Human immunodeficiency virus type I enhancer-b...   19.0
# 3                       Human immunodeficiency virus 1   18.0
# 4                       Human immunodeficiency virus 2   18.0
# ..                                                 ...    ...
# 179                               B-cell receptor CD22    4.0
# 180               Coagulation factor VII/tissue factor    4.0
# 181                                 Cytochrome P450 1A    4.0
# 182                                    Cytochrome P450    3.0
# 183       Mitochondrial complex I (NADH dehydrogenase)    0.0
#
#      species_group_flag target_chembl_id  \
# 0                 False    CHEMBL4523214
# 1                 False     CHEMBL613758
# 2                 False       CHEMBL2909
# 3                 False        CHEMBL378
# 4                 False        CHEMBL380
# ..                  ...              ...
# 179               False    CHEMBL1075279
# 180               False    CHEMBL2095194
# 181               False    CHEMBL3544905
# 182               False    CHEMBL4523986
# 183               False    CHEMBL2363065
#
#                                      target_components      target_type  \
# 0    [{'accession': 'P31629', 'component_descriptio...   SINGLE PROTEIN
# 1                                                   []         ORGANISM
# 2    [{'accession': 'P15822', 'component_descriptio...   SINGLE PROTEIN
# 3                                                   []         ORGANISM
# 4                                                   []         ORGANISM
# ..                                                 ...              ...
# 179  [{'accession': 'P35329', 'component_descriptio...   SINGLE PROTEIN
# 180  [{'accession': 'P08709', 'component_descriptio...  PROTEIN COMPLEX
# 181  [{'accession': 'P04798', 'component_descriptio...   PROTEIN FAMILY
# 182  [{'accession': 'P08684', 'component_descriptio...   PROTEIN FAMILY
# 183  [{'accession': 'P03923', 'component_descriptio...  PROTEIN COMPLEX
#
#      tax_id
# 0      9606
# 1     12721
# 2      9606
# 3     11676
# 4     11709
# ..      ...
# 179   10090
# 180    9606
# 181    9606
# 182    9606
# 183    9606
#
# [184 rows x 9 columns]

# %% [markdown]
# Selecting ID

# %%
selected_target = targets.target_chembl_id[8]
selected_target
# Out:
# 'CHEMBL243'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        32165                  []
# 1        None             None        32166                  []
# 2        None             None        32456                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL763424  Inhibitory concentration against HIV-1 Proteas...
# 1    CHEMBL763424  Inhibitory concentration against HIV-1 Proteas...
# 2    CHEMBL769366  In vivo antiviral activity (IC50) against HIV-...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#                   target_organism  \
# 0  Human immunodeficiency virus 1
# 1  Human immunodeficiency virus 1
# 2  Human immunodeficiency virus 1
#
#                                target_pref_name target_tax_id text_value  \
# 0  Human immunodeficiency virus type 1 protease         11676       None
# 1  Human immunodeficiency virus type 1 protease         11676       None
# 2  Human immunodeficiency virus type 1 protease         11676       None
#
#    toid  type    units    uo_units upper_value value
# 0  None  IC50  ug ml-1  UO_0000274        None  30.0
# 1  None  IC50  ug ml-1  UO_0000274        None  93.0
# 2  None  IC50       nM  UO_0000065        None  42.0
#
# [3 rows x 46 columns]

# %%
df.to_csv('bioactivity_data.csv', index = 'False')

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# # Directory generation in google drive

# %%
mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv

# %% [markdown]
# # List with time of created file

# %%
ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 1972
# -rw------- 1 root root 2018793 Oct  3 14:30 bioactivity_data.csv

# %% [markdown]
# # Handling Missing Data

# %%
print(df.columns)
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3449  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3450  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3451  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3452  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 3453  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           32165                  []    CHEMBL763424
# 1           32166                  []    CHEMBL763424
# 2           32456                  []    CHEMBL769366
# 3           32459                  []    CHEMBL769366
# 4           33353                  []    CHEMBL696055
# ...           ...                 ...             ...
# 3449     25090011                  []   CHEMBL5257798
# 3450     25090012                  []   CHEMBL5257798
# 3451     25105067                  []   CHEMBL5262984
# 3452     25105068                  []   CHEMBL5262984
# 3453     25105069                  []   CHEMBL5262984
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against HIV-1 Proteas...          B
# 1     Inhibitory concentration against HIV-1 Proteas...          B
# 2     In vivo antiviral activity (IC50) against HIV-...          B
# 3     In vivo antiviral activity (IC50) against HIV-...          B
# 4     Inhibitory activity was determined against HIV...          B
# ...                                                 ...        ...
# 3449                       Inhibition of HIV-1 protease          B
# 3450                       Inhibition of HIV-1 protease          B
# 3451   Inhibition of HIV-1 protease by FRET-based assay          B
# 3452   Inhibition of HIV-1 protease by FRET-based assay          B
# 3453   Inhibition of HIV-1 protease by FRET-based assay          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 3449                    None                   None  BAO_0000190  ...
# 3450                    None                   None  BAO_0000190  ...
# 3451                    None                   None  BAO_0000190  ...
# 3452                    None                   None  BAO_0000190  ...
# 3453                    None                   None  BAO_0000190  ...
#
#                      target_organism  \
# 0     Human immunodeficiency virus 1
# 1     Human immunodeficiency virus 1
# 2     Human immunodeficiency virus 1
# 3     Human immunodeficiency virus 1
# 4     Human immunodeficiency virus 1
# ...                              ...
# 3449  Human immunodeficiency virus 1
# 3450  Human immunodeficiency virus 1
# 3451  Human immunodeficiency virus 1
# 3452  Human immunodeficiency virus 1
# 3453  Human immunodeficiency virus 1
#
#                                   target_pref_name target_tax_id text_value  \
# 0     Human immunodeficiency virus type 1 protease         11676       None
# 1     Human immunodeficiency virus type 1 protease         11676       None
# 2     Human immunodeficiency virus type 1 protease         11676       None
# 3     Human immunodeficiency virus type 1 protease         11676       None
# 4     Human immunodeficiency virus type 1 protease         11676       None
# ...                                            ...           ...        ...
# 3449  Human immunodeficiency virus type 1 protease         11676       None
# 3450  Human immunodeficiency virus type 1 protease         11676       None
# 3451  Human immunodeficiency virus type 1 protease         11676       None
# 3452  Human immunodeficiency virus type 1 protease         11676       None
# 3453  Human immunodeficiency virus type 1 protease         11676       None
#
#       toid  type    units    uo_units upper_value   value
# 0     None  IC50  ug ml-1  UO_0000274        None    30.0
# 1     None  IC50  ug ml-1  UO_0000274        None    93.0
# 2     None  IC50       nM  UO_0000065        None    42.0
# 3     None  IC50       nM  UO_0000065        None  1000.0
# 4     None  IC50       nM  UO_0000065        None     4.0
# ...    ...   ...      ...         ...         ...     ...
# 3449  None  IC50       uM  UO_0000065        None     2.0
# 3450  None  IC50       nM  UO_0000065        None    0.01
# 3451  None  IC50       nM  UO_0000065        None     4.2
# 3452  None  IC50       nM  UO_0000065        None    11.8
# 3453  None  IC50       nM  UO_0000065        None     9.8
#
# [3356 rows x 46 columns]

# %%
df2.molecule_chembl_id
# Out:
# 0          CHEMBL9650
# 1        CHEMBL273396
# 2        CHEMBL108102
# 3        CHEMBL322033
# 4         CHEMBL20143
#             ...
# 3449    CHEMBL5284565
# 3450     CHEMBL478728
# 3451     CHEMBL159580
# 3452    CHEMBL5268749
# 3453    CHEMBL5274597
# Name: molecule_chembl_id, Length: 3356, dtype: object

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL9650  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 1          CHEMBL273396  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 2          CHEMBL108102  COC(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(O)CN(Cc...
# 3          CHEMBL322033  COC(=O)N(C)C(C(=O)N[C@@H](Cc1ccccc1)[C@H](O)CN...
# 4           CHEMBL20143  CC(C)[C@H](NC(=O)OCc1ccccc1)C(=O)NC(Cc1ccc(OCc...
# ...                 ...                                                ...
# 3449      CHEMBL5284565                 O=c1oc2cc(O)ccc2c(O)c1-c1ccc(O)cc1
# 3450       CHEMBL478728  CCOC(=O)C(C(C)=O)C(c1cccc([N+](=O)[O-])c1)c1c(...
# 3451       CHEMBL159580  COc1ccc(S(=O)(=O)N(CC(C)C)C[C@@H](O)[C@H](Cc2c...
# 3452      CHEMBL5268749  COc1ccc(S(=O)(=O)N(CC(C)C)C[C@@H](O)[C@H](Cc2c...
# 3453      CHEMBL5274597  CCC(C)(C)C(=O)C(=O)N1CCCCC1C(=O)OC(CCc1ccc(OC)...
#
#      standard_value
# 0              30.0
# 1              93.0
# 2              42.0
# 3            1000.0
# 4               4.0
# ...             ...
# 3449         2000.0
# 3450           0.01
# 3451            4.2
# 3452           11.8
# 3453            9.8
#
# [3356 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(mol_cid)], axis=1)
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL9650  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 1          CHEMBL273396  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 2          CHEMBL108102  COC(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(O)CN(Cc...
# 3          CHEMBL322033  COC(=O)N(C)C(C(=O)N[C@@H](Cc1ccccc1)[C@H](O)CN...
# 4           CHEMBL20143  CC(C)[C@H](NC(=O)OCc1ccccc1)C(=O)NC(Cc1ccc(OCc...
# ...                 ...                                                ...
# 2608                NaN                                                NaN
# 2617                NaN                                                NaN
# 2651                NaN                                                NaN
# 2679                NaN                                                NaN
# 3176                NaN                                                NaN
#
#      standard_value                                                  0
# 0              30.0  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 1              93.0  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 2              42.0  COC(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(O)CN(Cc...
# 3            1000.0  COC(=O)N(C)C(C(=O)N[C@@H](Cc1ccccc1)[C@H](O)CN...
# 4               4.0  CC(C)[C@H](NC(=O)OCc1ccccc1)C(=O)NC(Cc1ccc(OCc...
# ...             ...                                                ...
# 2608            NaN  CC(C)(C)OC(=O)N[C@@H](Cc1ccccc1)[C@H](O)CNC(C(...
# 2617            NaN  Cc1cc(SC2=C(O)OC(CCc3ccc(O)cc3)(C(C)C)CC2=O)c(...
# 2651            NaN  CC(C)(C)NC(=O)c1ccccc1C[C@@H](O)[C@H](Cc1ccccc...
# 2679            NaN  NC(=O)CC(N)C(=O)N[C@@H](Cc1ccccc1)[C@H](O)CN[C...
# 3176            NaN  CC(C)CN(C[C@@H](O)[C@H](Cc1ccccc1)NC(=O)c1cc2c...
#
# [3454 rows x 4 columns]

# %%
df4 = pd.read_csv('bioactivity_preprocessed_data.csv')
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")
    bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL9650  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 1          CHEMBL273396  CCC(C)[C@H](NC(=O)[C@@H]1CCCN1[P@@](=O)(OC)[C@...
# 2          CHEMBL108102  COC(=O)N[C@H](C(=O)N[C@@H](Cc1ccccc1)C(O)CN(Cc...
# 3          CHEMBL322033  COC(=O)N(C)C(C(=O)N[C@@H](Cc1ccccc1)[C@H](O)CN...
# 4           CHEMBL20143  CC(C)[C@H](NC(=O)OCc1ccccc1)C(=O)NC(Cc1ccc(OCc...
# ...                 ...                                                ...
# 3351      CHEMBL5284565                 O=c1oc2cc(O)ccc2c(O)c1-c1ccc(O)cc1
# 3352       CHEMBL478728  CCOC(=O)C(C(C)=O)C(c1cccc([N+](=O)[O-])c1)c1c(...
# 3353       CHEMBL159580  COc1ccc(S(=O)(=O)N(CC(C)C)C[C@@H](O)[C@H](Cc2c...
# 3354      CHEMBL5268749  COc1ccc(S(=O)(=O)N(CC(C)C)C[C@@H](O)[C@H](Cc2c...
# 3355      CHEMBL5274597  CCC(C)(C)C(=O)C(=O)N1CCCCC1C(=O)OC(CCc1ccc(OC)...
#
#       standard_value         class
# 0              30.00        active
# 1              93.00        active
# 2              42.00        active
# 3            1000.00        active
# 4               4.00        active
# ...              ...           ...
# 3351         2000.00  intermediate
# 3352            0.01           NaN
# 3353            4.20           NaN
# 3354           11.80           NaN
# 3355            9.80           NaN
#
# [3356 rows x 4 columns]

# %%
df5.to_csv('bioactivity_preprocessed_data.csv', index=False)
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
