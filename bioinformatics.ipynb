# %% [markdown]
# <a href="https://colab.research.google.com/github/Meet2197/ChEMBL/blob/main/bioinformatics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install chembl-webresource-client
# Out:
# Collecting chembl-webresource-client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (2.32.3)
# Collecting requests-cache~=1.2 (from chembl-webresource-client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl-webresource-client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl-webresource-client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl-webresource-client) (24.2.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl-webresource-client)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl-webresource-client) (4.3.6)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl-webresource-client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl-webresource-client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl-webresource-client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl-webresource-client) (1.16.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 2.3 MB/s eta 0:00:00
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.1 MB/s eta 0:00:00
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl-webresource-client
# Successfully installed cattrs-24.1.2 chembl-webresource-client-0.10.9 requests-cache-1.2.1 url-normalize-1.4.3

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client
target = new_client.target
target_query = target.search('human papillomavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'xref_id': 'P03120', 'xref_name': None, 'xre...
# 4    [{'xref_id': 'P08246', 'xref_name': None, 'xre...
# ..                                                 ...
# 111                                                 []
# 112                                                 []
# 113                                                 []
# 114                                                 []
# 115                                                 []
#
#                          organism  \
# 0            Human papillomavirus
# 1         human papillomavirus 11
# 2    Human papillomavirus type 16
# 3    Human papillomavirus type 16
# 4                    Homo sapiens
# ..                            ...
# 111             Rattus norvegicus
# 112                  Homo sapiens
# 113                  Homo sapiens
# 114                  Homo sapiens
# 115                  Homo sapiens
#
#                                         pref_name  score  species_group_flag  \
# 0                            Human papillomavirus   27.0               False
# 1                         human papillomavirus 11   23.0               False
# 2                    Human papillomavirus type 16   21.0               False
# 3      Human papillomavirus regulatory protein E2   19.0               False
# 4                              Leukocyte elastase   12.0               False
# ..                                            ...    ...                 ...
# 111              Protein kinase C, PKC; classical    5.0               False
# 112                          PKC alpha and beta-2    5.0               False
# 113                            Cytochrome P450 1A    4.0               False
# 114                               Cytochrome P450    3.0               False
# 115  Mitochondrial complex I (NADH dehydrogenase)    0.0               False
#
#     target_chembl_id                                  target_components  \
# 0       CHEMBL612319                                                 []
# 1       CHEMBL613717                                                 []
# 2       CHEMBL613205                                                 []
# 3         CHEMBL4656  [{'accession': 'P03120', 'component_descriptio...
# 4          CHEMBL248  [{'accession': 'P08246', 'component_descriptio...
# ..               ...                                                ...
# 111    CHEMBL2097168  [{'accession': 'P05696', 'component_descriptio...
# 112    CHEMBL3137267  [{'accession': 'P17252', 'component_descriptio...
# 113    CHEMBL3544905  [{'accession': 'P04798', 'component_descriptio...
# 114    CHEMBL4523986  [{'accession': 'P08684', 'component_descriptio...
# 115    CHEMBL2363065  [{'accession': 'P03923', 'component_descriptio...
#
#          target_type  tax_id
# 0           ORGANISM   10566
# 1           ORGANISM   10580
# 2           ORGANISM  333760
# 3     SINGLE PROTEIN  333760
# 4     SINGLE PROTEIN    9606
# ..               ...     ...
# 111   PROTEIN FAMILY   10116
# 112   PROTEIN FAMILY    9606
# 113   PROTEIN FAMILY    9606
# 114   PROTEIN FAMILY    9606
# 115  PROTEIN COMPLEX    9606
#
# [116 rows x 9 columns]

# %%
selected_target = targets.target_chembl_id[4]
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL612319'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       186318                  []
# 1        None             None       192326                  []
# 2        None             None       194676                  []
# 3        None             None      2601827                  []
# 4        None             None      2601828                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL697108  Inhibitory concentration against DNA-binding d...
# 1    CHEMBL697108  Inhibitory concentration against DNA-binding d...
# 2    CHEMBL697108  Inhibitory concentration against DNA-binding d...
# 3   CHEMBL1033999    Antiviral activity against Human papillomavirus
# 4   CHEMBL1033999    Antiviral activity against Human papillomavirus
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# 1          F                    None                   None  BAO_0000190  ...
# 2          F                    None                   None  BAO_0000190  ...
# 3          F                    None                   None  BAO_0000190  ...
# 4          F                    None                   None  BAO_0000190  ...
#
#         target_organism      target_pref_name target_tax_id text_value  toid  \
# 0  Human papillomavirus  Human papillomavirus         10566       None  None
# 1  Human papillomavirus  Human papillomavirus         10566       None  None
# 2  Human papillomavirus  Human papillomavirus         10566       None  None
# 3  Human papillomavirus  Human papillomavirus         10566       None  None
# 4  Human papillomavirus  Human papillomavirus         10566       None  None
#
#    type units    uo_units upper_value   value
# 0  IC50    uM  UO_0000065        None   150.0
# 1  IC50    uM  UO_0000065        None    75.0
# 2  IC50    uM  UO_0000065        None    10.0
# 3  IC50    uM  UO_0000065        None  0.0043
# 4  IC50    uM  UO_0000065        None  0.0045
#
# [5 rows x 46 columns]

# %%
df.standard_type.unique()
df.to_csv('bioactivity_data.csv', index = 'False')
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
mkdir "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv
